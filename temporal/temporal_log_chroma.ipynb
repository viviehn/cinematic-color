# %%
import pandas as pd
import numpy as np

import io
import os
import time

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from skimage import color
from skimage.transform import rescale, resize

import moviepy.editor as mp

import cv2

yt_url_prefix = 'https://www.youtube.com/watch?v='
dataset_folder = "../../data"

# %%
cinematic_folder = "../../data"
cinematic = [
    os.path.join(cinematic_folder, f)
    for f 
    in os.listdir(cinematic_folder) 
    if f[-4:] == ".mp4"
]
len(cinematic), cinematic[0]
# Out:
# (1855, '../../data/xV5udqNpP94.mp4')

# %%
casual_folder = "../../data/casual"
casual = [
    os.path.join(casual_folder, f)
    for f 
    in os.listdir(casual_folder) 
    if f[-4:] == ".mp4"
]
len(casual), casual[0]
# Out:
# (20, '../../data/casual/sCFi2O1vyWQ.mp4')

# %%
def rgb_to_chroma_hist(rgb, bin_res):
    # RGB to Chroma Hist
    rgb = rgb / 255
    rgb_rsz_resh = np.reshape(rgb, (-1, 3))
    rgb_uv = rgb_rsz_resh[:,:2]
    rgb_uv[:,0] = np.log(rgb_rsz_resh[:,1]/(rgb_rsz_resh[:,0]+1e-6)+1e-6)
    rgb_uv[:,1] = np.log(rgb_rsz_resh[:,1]/(rgb_rsz_resh[:,2]+1e-6)+1e-6)
    #print(rgb_rsz_resh)
    hist, edges = np.histogramdd(rgb_uv, bins=bin_res, range=[[-1,1],[-1,1]], density=False)
    hist /= hist.max()
    hist = np.sqrt(hist)
    return hist, edges

# Old version adapted directly from Cecilia
"""def rgb_to_chroma_hist(rgb, bin_res):
    # RGB to Chroma Hist
    rgb_rsz = resize(rgb, (rgb.shape[0], rgb.shape[1]), anti_aliasing=True)
    rgb_rsz_resh = np.reshape(rgb_rsz, (-1, 3))
    rgb_uv = rgb_rsz_resh[:,:2]
    rgb_uv[:,0] = np.log(rgb_rsz_resh[:,1]/(rgb_rsz_resh[:,0]+1e-6)+1e-6)
    rgb_uv[:,1] = np.log(rgb_rsz_resh[:,1]/(rgb_rsz_resh[:,2]+1e-6)+1e-6)
    #print(rgb_rsz_resh)
    hist, edges = np.histogramdd(rgb_uv, bins=bin_res, range=[[-1,1],[-1,1]], density=False)
    hist /= hist.max()
    hist = np.sqrt(hist)
    return hist, edges"""

def chroma_hist_to_rgb_vis(hist, edges, bin_res):
    # Hist to Image
    hist_vis = np.zeros((hist.shape[0], hist.shape[1], 3))
    # green
    hist_vis[:, :, 1] = hist
    # red
    hist_vis[:, :, 0] = hist / np.exp(edges[0][:-1])[:, None]
    # blue
    hist_vis[:, :, 2] = hist / np.exp(edges[1][:-1])[None, :]

    hist_vis = np.clip(hist_vis,0,1)
    hist_vis *= 255
    hist_vis = np.uint8(hist_vis)
    return hist_vis


# Old version adapted directly from Cecilia
"""def chroma_hist_to_rgb_vis(hist, edges, bin_res):
    # Hist to Image
    hist_vis = np.zeros((hist.shape[0], hist.shape[1], 3))
    #rgb_vis = np.zeros((hist.shape[0], hist.shape[1], 3))

    for i in range(bin_res[0]):
        for j in range(bin_res[1]):
            green = hist[i,j]
            red = green / np.exp(edges[0][i]) 
            blue = green / np.exp(edges[1][j])
    #         print(red)
            hist_vis[i, j, 0] = red
            hist_vis[i, j, 1] = green
            hist_vis[i, j, 2] = blue

    hist_vis = np.clip(hist_vis,0,1)
    hist_vis *= 255
    hist_vis = np.uint8(hist_vis)
    return hist_vis"""
# Out:
# 'def chroma_hist_to_rgb_vis(hist, edges, bin_res):\n    # Hist to Image\n    hist_vis = np.zeros((hist.shape[0], hist.shape[1], 3))\n    #rgb_vis = np.zeros((hist.shape[0], hist.shape[1], 3))\n\n    for i in range(bin_res[0]):\n        for j in range(bin_res[1]):\n            green = hist[i,j]\n            red = green / np.exp(edges[0][i]) \n            blue = green / np.exp(edges[1][j])\n    #         print(red)\n            hist_vis[i, j, 0] = red\n            hist_vis[i, j, 1] = green\n            hist_vis[i, j, 2] = blue\n\n    hist_vis = np.clip(hist_vis,0,1)\n    hist_vis *= 255\n    hist_vis = np.uint8(hist_vis)\n    return hist_vis'

# %%
def print_ndarray_metrics(m, name=None):
    print(name)
    print(f"Shape: {m.shape}")
    print(f"Dtype: {m.dtype}")
    print(f"Min: {m.min()}")
    print(f"Max: {m.max()}")
    print(f"Mean: {m.mean()}")
    print(f"Std: {m.std()}")
    print(m)

# %%
# histogram similarity metrics
def norm_hist(H):
    return H / H.sum()

def hist_correlation(H1, H2):
    H1_bar = H1.mean()
    H2_bar = H2.mean()
    num = ((H1 - H1_bar)*(H2 - H2_bar)).sum()
    denom = ((H1 - H1_bar)**2).sum() * ((H2 - H2_bar)**2).sum()
    denom = denom ** 0.5
    return num / denom

def hist_intersection(H1, H2):
    return np.minimum(H1, H2).sum()

def hist_bhattacharyya(H1, H2):
    return -np.log(np.sqrt(H1*H2).sum())

def compare_histograms(H1, H2, data_dict=None, comparison_functions=[hist_correlation, hist_intersection, hist_bhattacharyya]):
    H1, H2 = norm_hist(H1), norm_hist(H2) # Convert to probability distribution
    if data_dict is None:
        data_dict = {f.__name__: [] for f in comparison_functions} 
    for f in comparison_functions:
        data_dict[f.__name__].append(f(H1, H2))
    return data_dict

# %%
class Timer:
    def __init__(self, name=""):
        self.name=name
        self.time = 0
        self.num_calls = 0
        self._last_start_time = 0
    
    def start(self):
        self._last_start_time = time.time()
        
    def stop(self):
        self.time += time.time() - self._last_start_time
        self.num_calls += 1

    def print_avg(self):
        if self.num_calls > 0:
            print(f"Average time for function {self.name}: {self.time / self.num_calls}")

# %%
def collect_video_stats(
        vid_file_dir,
        vid_cut_folder,
        lch_vis_folder,
        subsequent_frame_folder,
        subsequent_cut_folder,
        cut_stddev_folder,
        lch_vis_recalculate = False,
        subsequent_frame_recalculate = False,
        subsequent_cut_recalculate = False,
        cut_stddev_recalculate = False
    ):
    # Prep main constants
    vid_file = os.path.basename(vid_file_dir)
    yt_id = vid_file.split(".")[0]
    clip = mp.VideoFileClip(vid_file_dir)
    clip_resized = clip.resize(height=240) # make the height 240px ( According to moviePy documenation The width is then computed so that the width/height ratio is conserved.)
    frame_count = int(clip.fps * clip.duration)
    iter_time = Timer("Total Iteration")
    
    # Prep histogram constants
    bin_size = (50, 50)
    hist_time = Timer("hist")
    
    # Prep video cut constants
    vid_cut_file = f'{yt_id}_cuts.npy'
    vid_cut_dir = os.path.join(vid_cut_folder, vid_cut_file)
    vid_cuts = np.load(vid_cut_dir)
    #print(f"Vid Cuts: {vid_cuts}")
    
    # Prep log-chroma-histogram constants
    lch_vid_file = f"{yt_id}_rgb.avi"
    lch_vid_dir = os.path.join(lch_vis_folder,lch_vid_file)
    do_lch_vid = (not os.path.exists(lch_vid_dir)) or lch_vis_recalculate
    if do_lch_vid:
        vid_time = Timer("vis")
        vid_lch = cv2.VideoWriter(lch_vid_dir, cv2.VideoWriter_fourcc(*"MJPG"), clip.fps, bin_size)
#    else:
#        print("Skipping LCH Vis...")
    
    # Prep subsequent frame analysis constants
    subsequent_frame_file = f"{yt_id}_byFrame.csv"
    subsequent_frame_dir = os.path.join(
        subsequent_frame_folder,
        subsequent_frame_file
    )
    do_subsequent_frame = (not os.path.exists(subsequent_frame_dir)) or subsequent_frame_recalculate
    if do_subsequent_frame:
        H_frame_prev = None
        frame_wise_data = None # Signals to compare_histograms that we need to replace this with a data structure
#    else:
#        print("Skipping Subsequent Frame Analysis...")
    
    # Prep subsequent cut analysis constants
    subsequent_cut_file = f"{yt_id}_byCut.csv"
    subsequent_cut_dir = os.path.join(
        subsequent_cut_folder,
        subsequent_cut_file
    )
    do_subsequent_cut = (not os.path.exists(subsequent_cut_dir)) or subsequent_cut_recalculate
    H_cut = None
    H_cut_prev = None
    if do_subsequent_cut:
        cut_wise_data = None # Signals to compare_histograms that we need to replace this with a data structure
#    else:
#        print("Skipping Subsequent Cut Analysis...")
    
    # Prep cut sttdev analysis constants
    cut_stddev_file = f"{yt_id}_cutStddev.npy"
    cut_stddev_dir = os.path.join(
        cut_stddev_folder,
        cut_stddev_file
    )
    do_cut_stddev = (not os.path.exists(cut_stddev_dir)) or cut_stddev_recalculate
    if do_cut_stddev:
        cuts_for_stddev = []
#    else:
#        print("Skipping Cut StdDev Analysis")
    
    if do_lch_vid or do_subsequent_frame or do_subsequent_cut or do_cut_stddev:
        for i, f_rgb in enumerate(clip_resized.iter_frames()):
            iter_time.start()
            # Print status update if there are more frames to process
            print(f"Processing Frame {i}/{frame_count}", end="\r")

#            if i > 500:
#                break

            # Reset our histogram and collect data if we have encountered a cut
            if i in vid_cuts:
                if do_cut_stddev and H_cut is not None:
                    H_cut_n = norm_hist(H_cut)
                    #print_ndarray_metrics(H_cut_n, "H_cut_n")
                    cuts_for_stddev.append(H_cut_n)
                # Collect cut_wise stats
                if do_subsequent_cut and H_cut_prev is not None:
                    cut_wise_data = compare_histograms(H_cut, H_cut_prev, cut_wise_data)
                # (Re)set aggregation variables
                H_cut_prev = H_cut
                H_cut = np.zeros(bin_size)

            # Make Histogram
            hist_time.start()
            H_frame, edges = rgb_to_chroma_hist(f_rgb, bin_size)
            #print(edges)
            hist_time.stop()

            # Write visualized histogram to video
            if do_lch_vid:
                vid_time.start()
                H_frame_vis = chroma_hist_to_rgb_vis(H_frame, edges, bin_size)
                H_frame_vis = np.flip(H_frame_vis, axis=2) # Switch RGB to BGR (openCV standard)
                vid_time.stop()
                vid_lch.write(H_frame_vis)

            # Collect frame_wise stats
            if do_subsequent_frame and H_frame_prev is not None:
                frame_wise_data = compare_histograms(H_frame, H_frame_prev, frame_wise_data)

            # Increment
            H_cut += H_frame
            H_frame_prev = H_frame
            
            iter_time.stop()

        # Finish last iteration for some analyses:
        if do_cut_stddev:
            cuts_for_stddev.append(norm_hist(H_cut))
        if do_subsequent_cut:
            cut_wise_data = compare_histograms(H_cut, H_cut_prev, cut_wise_data)

        # Finalize log-chroma-histogram vis:
        if do_lch_vid:
            vid_lch.release()
            vid_time.print_avg()

        # Finalize log-chroma-histogram vis:
        hist_time.print_avg()

        # Finalize subsequent frame analysis:
        if do_subsequent_frame:
            pd.DataFrame(frame_wise_data).to_csv(subsequent_frame_dir) # Write DataFrame to file

        # Finalize subsequent cut analysis:
        if do_subsequent_cut:
            pd.DataFrame(cut_wise_data).to_csv(subsequent_cut_dir) # Write DataFrame to file

        # Finalize cut stddev analysis:
        if do_cut_stddev:
            #print(cuts_for_stddev)
            cuts_sttdev_stack = np.stack(cuts_for_stddev)
            #print_ndarray_metrics(cuts_sttdev_stack, "cuts_sttdev_stack")
            cuts_sttdev = np.nanstd(cuts_sttdev_stack, axis=0) # Ignoring
            if np.isnan(cuts_sttdev[0,0]): #Trying to avoid strange error
                print("Stddev Calculation Failed!")
                #print(cuts_for_stddev)
                #print_ndarray_metrics(cuts_sttdev, "cuts_sttdev")
            else:
                np.save(cut_stddev_dir, cuts_sttdev)
        
        # Show total iteration time:
        iter_time.print_avg()

        #plt.imshow(cuts_sttdev)
    #print()

# %%
def collect_temporal_stats(vid_files, start_index=0, *args, **kwargs):
    for i, vid_dir in enumerate(vid_files):
        if i < start_index:
            continue
        try:
            vid_file = os.path.basename(vid_dir)
            yt_id = vid_file.split(".")[0]
            print(f"Processing Video {vid_dir} - {i}/{len(vid_files)}")
            collect_video_stats(vid_dir, *args, **kwargs)
        except Exception as e:
            print(e)

# %%
collect_temporal_stats(
    cinematic,
    vid_cut_folder="../../data/cuts/",
    subsequent_frame_folder="../../data/analysis/variation_hist_metrics",
    subsequent_cut_folder="../../data/analysis/variation_hist_metrics",
    cut_stddev_folder="../../data/analysis/temporal_hist_std",
    lch_vis_folder="../../data/analysis/variation_hist_videos",
    subsequent_frame_recalculate = True,
    subsequent_cut_recalculate = True,
    cut_stddev_recalculate = True   
)
# Out:
# Processing Video ../../data/xV5udqNpP94.mp4 - 0/1855
# Average time for function hist: 0.005293032925342747
# Average time for function Total Iteration: 0.0055592226296310296
# Processing Video ../../data/TKPmGjVFbrY.mp4 - 1/1855
# Average time for function hist: 0.005045327516986046
# Average time for function Total Iteration: 0.005290417292548667
# Processing Video ../../data/uiA4B5Y63IQ.mp4 - 2/1855
# Average time for function hist: 0.005302805093312966
# Average time for function Total Iteration: 0.005567818232782892
# Processing Video ../../data/LeLsJfGmY_Y.mp4 - 3/1855
# Average time for function hist: 0.00480132800888042
# Average time for function Total Iteration: 0.0050645900928244295
# Processing Video ../../data/0WWzgGyAH6Y.mp4 - 4/1855
# Average time for function Total Iteration: 0.014489598985596415
# Processing Video ../../data/JOu3lbWyuic.mp4 - 295/1855
# Average time for function hist: 0.013056157513121894
# Average time for function Total Iteration: 0.01390700096138682
# Processing Video ../../data/2Byk9Is3TjY.mp4 - 296/1855
# Average time for function hist: 0.017952982469843563
# Average time for function Total Iteration: 0.01885677324855392
# Processing Video ../../data/bJcLRFWxRno.mp4 - 297/1855
# Average time for function hist: 0.01286767730541636
# Average time for function Total Iteration: 0.01375935085694798
# Processing Video ../../data/iwROgK94zcM.mp4 - 298/1855
# Average time for function hist: 0.012576328730291929
# Average time for function Total Iteration: 0.013410433736771189
# Processing Video ../../data/L9szn1QQfas.mp4 - 299/1855
# Average time for function hist: 0.017692175990969953
# Average time for function Total Iteration: 0.018587022541678527
# Processing Video ../../data/zmBDY-fSlIs.mp4 - 300/1855
# Average time for function hist: 0.01224605737009008
# Average time for function Total Iteration: 0.01333653935280008
# Processing Video ../../data/6EZCBSsBxko.mp4 - 301/1855
# Average time for function hist: 0.012356636408236026
# Average time for function Total Iteration: 0.013269733180429509
# Processing Video ../../data/c_Ne5g5F-WY.mp4 - 302/1855
# Average time for function hist: 0.010594076475348633
# Average time for function Total Iteration: 0.01153390543170707
# Processing Video ../../data/15syDwC000k.mp4 - 303/1855
# Average time for function hist: 0.013361220905084324
# Average time for function Total Iteration: 0.014312916265048915
# Processing Video ../../data/a_Hw4bAUj8A.mp4 - 304/1855
# Average time for function hist: 0.011340578626805417
# Average time for function Total Iteration: 0.012213145453882432
# Processing Video ../../data/sFXGrTng0gQ.mp4 - 305/1855
# Average time for function hist: 0.012975542530067947
# Average time for function Total Iteration: 0.013896573708255661
# Processing Video ../../data/LZrX9mffH8Y.mp4 - 306/1855
# Average time for function hist: 0.0134206475463568
# Average time for function Total Iteration: 0.014401884265974456
# Processing Video ../../data/-T3wnP91OnI.mp4 - 307/1855
# Average time for function hist: 0.014054561228185268
# Average time for function Total Iteration: 0.014987489726993588
# Processing Video ../../data/sJCjKQQOqT0.mp4 - 308/1855
# Average time for function hist: 0.012759160264698482
# Average time for function Total Iteration: 0.01366915363816821
# Processing Video ../../data/XVjDcUCui0w.mp4 - 309/1855
# ...
# Average time for function hist: 0.0046739323712454706
# Average time for function Total Iteration: 0.004937533851038869
# Processing Video ../../data/OIx8OGeEh9c.mp4 - 1657/1855
# Average time for function hist: 0.005373755224434592
# Average time for function Total Iteration: 0.0056401741376654
# Processing Video ../../data/cB3NW3O_OfE.mp4 - 1658/1855
# Average time for function hist: 0.004853110046414103
# Average time for function Total Iteration: 0.005101959566717429
# Processing Video ../../data/Q61YhARNOPg.mp4 - 1659/1855
# Average time for function hist: 0.0052342099198622654
# Average time for function Total Iteration: 0.005426060988556579
# Processing Video ../../data/cnNBqNb3taw.mp4 - 1660/1855
# Average time for function hist: 0.004687916690489859
# Average time for function Total Iteration: 0.0048785740192738404
# Processing Video ../../data/QheoYw1BKJ4.mp4 - 1661/1855
# Average time for function hist: 0.004863579057886383
# Processing Video ../../data/fUjicxMPDzs.mp4 - 1816/1855
# Average time for function hist: 0.004816011482631443
# Average time for function Total Iteration: 0.005085237707707659
# Processing Video ../../data/Im4odVLNxqo.mp4 - 1817/1855
# Average time for function hist: 0.004881131972140287
# Average time for function Total Iteration: 0.005149364125232383
# Processing Video ../../data/mwbLivFNZok.mp4 - 1818/1855
# Average time for function hist: 0.004048419054553994
# Average time for function Total Iteration: 0.004225661994701806
# Processing Video ../../data/iojhqm0JTW4.mp4 - 1819/1855
# Average time for function hist: 0.0063660562584645815
# Average time for function Total Iteration: 0.0066121371379662675
# Processing Video ../../data/4t2tdKD9tPs.mp4 - 1820/1855
# Average time for function hist: 0.004803954278631435
# Average time for function Total Iteration: 0.004989366842796767
# Processing Video ../../data/2gx8Sx8Ushk.mp4 - 1821/1855
# Average time for function hist: 0.0041591987095541665
# Average time for function Total Iteration: 0.004346940155656944
# Processing Video ../../data/6UjbmIoM_aE.mp4 - 1822/1855
# Average time for function hist: 0.005195111262231428
# Average time for function Total Iteration: 0.00547518720304777
# Processing Video ../../data/dLmKio67pVQ.mp4 - 1823/1855
# Average time for function hist: 0.004744998699836666
# Average time for function Total Iteration: 0.0050131337353964975
# Processing Video ../../data/kJ27kgmhI6Q.mp4 - 1824/1855
# Average time for function hist: 0.004599262686336742
# Average time for function Total Iteration: 0.004852080948081496
# Processing Video ../../data/z7zl_t48CMc.mp4 - 1825/1855
# Average time for function hist: 0.005268320794617561
# Average time for function Total Iteration: 0.005541835630413313
# Processing Video ../../data/y0f_e0ZJLvA.mp4 - 1826/1855
# Average time for function hist: 0.003717400462311857
# Average time for function Total Iteration: 0.0039060405072043926
# Processing Video ../../data/JOsEU5oYpTA.mp4 - 1827/1855
# Average time for function hist: 0.00462452250066224
# Average time for function Total Iteration: 0.004893561416390669
# Processing Video ../../data/21jdGrCtSak.mp4 - 1828/1855
# Average time for function hist: 0.0038140666825631497
# Average time for function Total Iteration: 0.004001698028784813
# Processing Video ../../data/BoohRoVA9WQ.mp4 - 1829/1855
# Average time for function hist: 0.004486089523788126
# Average time for function Total Iteration: 0.004731671906949992
# Processing Video ../../data/C6PbWhWGUrY.mp4 - 1830/1855
# Average time for function hist: 0.005391581763176562
# Average time for function Total Iteration: 0.005656383980885219
# Processing Video ../../data/cMKX2tE5Luk.mp4 - 1831/1855
# Average time for function hist: 0.004892985737592432
# Average time for function Total Iteration: 0.0051611417162083445
# Processing Video ../../data/Sq5CIH0duMk.mp4 - 1832/1855
# Average time for function hist: 0.005244445938595458
# Average time for function Total Iteration: 0.0055016717163507345
# Processing Video ../../data/bN7ksFEVO9U.mp4 - 1833/1855
# Average time for function hist: 0.004850649542461604
# Average time for function Total Iteration: 0.005124562418467177
# Processing Video ../../data/pnzLRDDijW0.mp4 - 1834/1855
# Average time for function hist: 0.004036632512475247
# Average time for function Total Iteration: 0.004232322016069966
# Processing Video ../../data/cSp1dM2Vj48.mp4 - 1835/1855
# Average time for function hist: 0.004983409995078766
# Average time for function Total Iteration: 0.0052533671923771985
# Processing Video ../../data/kDP8ERAUnZc.mp4 - 1836/1855
# Average time for function hist: 0.004620285928127368
# Average time for function Total Iteration: 0.004807941453943866
# Processing Video ../../data/N4wNv1zuYDc.mp4 - 1837/1855
# Average time for function hist: 0.004510950886600364
# Average time for function Total Iteration: 0.004723156905161291
# Processing Video ../../data/PzzzdDW6HDo.mp4 - 1838/1855
# Average time for function hist: 0.005199120560183484
# Average time for function Total Iteration: 0.005412636359322031
# Processing Video ../../data/oDcaZ3StTfI.mp4 - 1839/1855
# Average time for function hist: 0.0068814416542890165
# Average time for function Total Iteration: 0.007149104777439637
# Processing Video ../../data/3zuRkQSx5gs.mp4 - 1840/1855
# Average time for function hist: 0.003794749200244134
# Average time for function Total Iteration: 0.003982687409594446
# Processing Video ../../data/eh_qPcQoFK0.mp4 - 1841/1855
# Average time for function hist: 0.00447220073805915
# Average time for function Total Iteration: 0.00472710132598877
# Processing Video ../../data/aStYWD25fAQ.mp4 - 1842/1855
# Average time for function hist: 0.004548039866405433
# Average time for function Total Iteration: 0.004795483123830033
# Processing Video ../../data/F_PfTl63qQQ.mp4 - 1843/1855
# Processing Frame 574/2905

# %%
collect_temporal_stats(
    casual,
    vid_cut_folder="../../data/casual/cuts/",
    subsequent_frame_folder="../../data/casual/analysis/variation_hist_metrics",
    subsequent_cut_folder="../../data/casual/analysis/variation_hist_metrics",
    cut_stddev_folder="../../data/casual/analysis/temporal_hist_std",
    lch_vis_folder="../../data/casual/analysis/variation_hist_videos",
    subsequent_frame_recalculate = True,
    subsequent_cut_recalculate = True,
    cut_stddev_recalculate = True
)
# Out:
# Processing Video ../../data/casual/sCFi2O1vyWQ.mp4 - 0/20
# Average time for function hist: 0.0054108516893456105
# Average time for function Total Iteration: 0.005660894796429461
# Processing Video ../../data/casual/rtMSMWm-xw0.mp4 - 1/20
# Average time for function hist: 0.005868135003837461
# Average time for function Total Iteration: 0.006139814231542769
# Processing Video ../../data/casual/ggNIcxiUv6Q.mp4 - 2/20
# Average time for function hist: 0.005248494938423821
# Average time for function Total Iteration: 0.0054978268827655
# Processing Video ../../data/casual/J_EDZOodc14.mp4 - 3/20
# Average time for function hist: 0.005725422285268554
# Average time for function Total Iteration: 0.005995239727991435
# Processing Video ../../data/casual/WE5uaL0urok.mp4 - 4/20
# Average time for function hist: 0.005665032774137301
# Average time for function Total Iteration: 0.0059349195143075075
# Processing Video ../../data/casual/FZ7wBmLvcSA.mp4 - 5/20
# Average time for function hist: 0.005582785083050967
# Average time for function Total Iteration: 0.005862677404275671
# Processing Video ../../data/casual/bHKQfui91yc.mp4 - 6/20
# Average time for function hist: 0.005215367461261534
# Average time for function Total Iteration: 0.005473727106152328
# Processing Video ../../data/casual/yAFmSm5l8gE.mp4 - 7/20
# Average time for function hist: 0.0056242412761322545
# Average time for function Total Iteration: 0.005878818339276261
# Processing Video ../../data/casual/I_1oQYpONjs.mp4 - 8/20
# Processing Frame 8115/17257
