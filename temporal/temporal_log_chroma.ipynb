# %%
import pandas as pd
import numpy as np

import io
import os
import time

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from skimage import color
from skimage.transform import rescale, resize

import moviepy.editor as mp

import cv2

yt_url_prefix = 'https://www.youtube.com/watch?v='
dataset_folder = "../../data"

# %%
cinematic = os.listdir(dataset_folder)
cinematic = [f for f in cinematic if f[-4:] == ".mp4"]
len(cinematic)
# Out:
# 1855

# %%
def rgb_to_chroma_hist(rgb, bin_res):
    # RGB to Chroma Hist
    rgb = rgb / 255
    rgb_rsz_resh = np.reshape(rgb, (-1, 3))
    rgb_uv = rgb_rsz_resh[:,:2]
    rgb_uv[:,0] = np.log(rgb_rsz_resh[:,1]/(rgb_rsz_resh[:,0]+1e-6)+1e-6)
    rgb_uv[:,1] = np.log(rgb_rsz_resh[:,1]/(rgb_rsz_resh[:,2]+1e-6)+1e-6)
    #print(rgb_rsz_resh)
    hist, edges = np.histogramdd(rgb_uv, bins=bin_res, range=[[-1,1],[-1,1]], density=False)
    hist /= hist.max()
    hist = np.sqrt(hist)
    return hist, edges

# Old version adapted directly from Cecilia
"""def rgb_to_chroma_hist(rgb, bin_res):
    # RGB to Chroma Hist
    rgb_rsz = resize(rgb, (rgb.shape[0], rgb.shape[1]), anti_aliasing=True)
    rgb_rsz_resh = np.reshape(rgb_rsz, (-1, 3))
    rgb_uv = rgb_rsz_resh[:,:2]
    rgb_uv[:,0] = np.log(rgb_rsz_resh[:,1]/(rgb_rsz_resh[:,0]+1e-6)+1e-6)
    rgb_uv[:,1] = np.log(rgb_rsz_resh[:,1]/(rgb_rsz_resh[:,2]+1e-6)+1e-6)
    #print(rgb_rsz_resh)
    hist, edges = np.histogramdd(rgb_uv, bins=bin_res, range=[[-1,1],[-1,1]], density=False)
    hist /= hist.max()
    hist = np.sqrt(hist)
    return hist, edges"""

def chroma_hist_to_rgb_vis(hist, edges, bin_res):
    # Hist to Image
    hist_vis = np.zeros((hist.shape[0], hist.shape[1], 3))
    # green
    hist_vis[:, :, 1] = hist
    # red
    hist_vis[:, :, 0] = hist / np.exp(edges[0][:-1])[:, None]
    # blue
    hist_vis[:, :, 2] = hist / np.exp(edges[1][:-1])[None, :]

    hist_vis = np.clip(hist_vis,0,1)
    hist_vis *= 255
    hist_vis = np.uint8(hist_vis)
    return hist_vis


# Old version adapted directly from Cecilia
"""def chroma_hist_to_rgb_vis(hist, edges, bin_res):
    # Hist to Image
    hist_vis = np.zeros((hist.shape[0], hist.shape[1], 3))
    #rgb_vis = np.zeros((hist.shape[0], hist.shape[1], 3))

    for i in range(bin_res[0]):
        for j in range(bin_res[1]):
            green = hist[i,j]
            red = green / np.exp(edges[0][i]) 
            blue = green / np.exp(edges[1][j])
    #         print(red)
            hist_vis[i, j, 0] = red
            hist_vis[i, j, 1] = green
            hist_vis[i, j, 2] = blue

    hist_vis = np.clip(hist_vis,0,1)
    hist_vis *= 255
    hist_vis = np.uint8(hist_vis)
    return hist_vis"""
# Out:
# 'def chroma_hist_to_rgb_vis(hist, edges, bin_res):\n    # Hist to Image\n    hist_vis = np.zeros((hist.shape[0], hist.shape[1], 3))\n    #rgb_vis = np.zeros((hist.shape[0], hist.shape[1], 3))\n\n    for i in range(bin_res[0]):\n        for j in range(bin_res[1]):\n            green = hist[i,j]\n            red = green / np.exp(edges[0][i]) \n            blue = green / np.exp(edges[1][j])\n    #         print(red)\n            hist_vis[i, j, 0] = red\n            hist_vis[i, j, 1] = green\n            hist_vis[i, j, 2] = blue\n\n    hist_vis = np.clip(hist_vis,0,1)\n    hist_vis *= 255\n    hist_vis = np.uint8(hist_vis)\n    return hist_vis'

# %%
def print_ndarray_metrics(m, name=None):
    print(name)
    print(f"Shape: {m.shape}")
    print(f"Dtype: {m.dtype}")
    print(f"Min: {m.min()}")
    print(f"Max: {m.max()}")
    print(f"Mean: {m.mean()}")
    print(f"Std: {m.std()}")
    print(m)

# %%
# histogram similarity metrics
def norm_hist(H):
    return H / H.size

def hist_correlation(H1, H2):
    H1_bar = H1.mean()
    H2_bar = H2.mean()
    num = ((H1 - H1_bar)*(H2 - H2_bar)).sum()
    denom = ((H1 - H1_bar)**2).sum() * ((H2 - H2_bar)**2).sum()
    denom = denom ** 0.5
    return num / denom

def hist_intersection(H1, H2):
    return np.minimum(H1, H2).sum()

def hist_bhattacharyya(H1, H2):
    return -np.log(np.sqrt(H1*H2).sum())

def compare_histograms(H1, H2, data_dict=None, comparison_functions=[hist_correlation, hist_intersection, hist_bhattacharyya]):
    H1, H2 = norm_hist(H1), norm_hist(H2) # Convert to probability distribution
    if data_dict is None:
        data_dict = {f.__name__: [] for f in comparison_functions} 
    for f in comparison_functions:
        data_dict[f.__name__].append(f(H1, H2))
    return data_dict

# %%
class Timer:
    def __init__(self, name=""):
        self.name=name
        self.time = 0
        self.num_calls = 0
        self._last_start_time = 0
    
    def start(self):
        self._last_start_time = time.time()
        
    def stop(self):
        self.time += time.time() - self._last_start_time
        self.num_calls += 1

    def print_avg(self):
        if self.num_calls > 0:
            print(f"Average time for function {self.name}: {self.time / self.num_calls}")

# %%
def collect_video_stats(
        vid_file_dir,
        vid_cut_folder,
        lch_vis_folder,
        subsequent_frame_folder,
        subsequent_cut_folder,
        cut_stddev_folder
    ):
    # Prep main constants
    vid_file = os.path.basename(vid_file_dir)
    yt_id = vid_file.split(".")[0]
    clip = mp.VideoFileClip(vid_file_dir)
    clip_resized = clip.resize(height=240) # make the height 240px ( According to moviePy documenation The width is then computed so that the width/height ratio is conserved.)
    frame_count = int(clip.fps * clip.duration)
    iter_time = Timer("Total Iteration")
    
    # Prep histogram constants
    bin_size = (50, 50)
    hist_time = Timer("hist")
    
    # Prep video cut constants
    vid_cut_file = f'{yt_id}_cuts.npy'
    vid_cut_dir = os.path.join(vid_cut_folder, vid_cut_file)
    vid_cuts = np.load(vid_cut_dir)
    #print(f"Vid Cuts: {vid_cuts}")
    
    # Prep log-chroma-histogram constants
    lch_vid_file = f"{yt_id}_rgb.avi"
    lch_vid_dir = os.path.join(lch_vis_folder,lch_vid_file)
    do_lch_vid = not os.path.exists(lch_vid_dir)
    if do_lch_vid:
        vid_time = Timer("vis")
        vid_lch = cv2.VideoWriter(lch_vid_dir, cv2.VideoWriter_fourcc(*"MJPG"), clip.fps, bin_size)
#    else:
#        print("Skipping LCH Vis...")
    
    # Prep subsequent frame analysis constants
    subsequent_frame_file = f"{yt_id}_byFrame.csv"
    subsequent_frame_dir = os.path.join(
        subsequent_frame_folder,
        subsequent_frame_file
    )
    do_subsequent_frame = not os.path.exists(subsequent_frame_dir)
    if do_subsequent_frame:
        H_frame_prev = None
        frame_wise_data = None # Signals to compare_histograms that we need to replace this with a data structure
#    else:
#        print("Skipping Subsequent Frame Analysis...")
    
    # Prep subsequent cut analysis constants
    subsequent_cut_file = f"{yt_id}_byCut.csv"
    subsequent_cut_dir = os.path.join(
        subsequent_cut_folder,
        subsequent_cut_file
    )
    do_subsequent_cut = not os.path.exists(subsequent_cut_dir)
    H_cut = None
    H_cut_prev = None
    if do_subsequent_cut:
        cut_wise_data = None # Signals to compare_histograms that we need to replace this with a data structure
#    else:
#        print("Skipping Subsequent Cut Analysis...")
    
    # Prep cut sttdev analysis constants
    cut_stddev_file = f"{yt_id}_cutStddev.npy"
    cut_stddev_dir = os.path.join(
        cut_stddev_folder,
        cut_stddev_file
    )
    do_cut_stddev = not os.path.exists(cut_stddev_dir)
    if do_cut_stddev:
        cuts_for_stddev = []
#    else:
#        print("Skipping Cut StdDev Analysis")
    
    if do_lch_vid or do_subsequent_frame or do_subsequent_cut or do_cut_stddev:
        for i, f_rgb in enumerate(clip_resized.iter_frames()):
            iter_time.start()
            # Print status update if there are more frames to process
            print(f"Processing Frame {i}/{frame_count}", end="\r")

#            if i > 500:
#                break

            # Reset our histogram and collect data if we have encountered a cut
            if i in vid_cuts:
                if do_cut_stddev and H_cut is not None:
                    H_cut_n = norm_hist(H_cut)
                    #print_ndarray_metrics(H_cut_n, "H_cut_n")
                    cuts_for_stddev.append(H_cut_n)
                # Collect cut_wise stats
                if do_subsequent_cut and H_cut_prev is not None:
                    cut_wise_data = compare_histograms(H_cut, H_cut_prev, cut_wise_data)
                # (Re)set aggregation variables
                H_cut_prev = H_cut
                H_cut = np.zeros(bin_size)

            # Make Histogram
            hist_time.start()
            H_frame, edges = rgb_to_chroma_hist(f_rgb, bin_size)
            #print(edges)
            hist_time.stop()

            # Write visualized histogram to video
            if do_lch_vid:
                vid_time.start()
                H_frame_vis = chroma_hist_to_rgb_vis(H_frame, edges, bin_size)
                H_frame_vis = np.flip(H_frame_vis, axis=2) # Switch RGB to BGR (openCV standard)
                vid_time.stop()
                vid_lch.write(H_frame_vis)

            # Collect frame_wise stats
            if do_subsequent_frame and H_frame_prev is not None:
                frame_wise_data = compare_histograms(H_frame, H_frame_prev, frame_wise_data)

            # Increment
            H_cut += H_frame
            H_frame_prev = H_frame
            
            iter_time.stop()

        # Finish last iteration for some analyses:
        if do_cut_stddev:
            cuts_for_stddev.append(norm_hist(H_cut))
        if do_subsequent_cut:
            cut_wise_data = compare_histograms(H_cut, H_cut_prev, cut_wise_data)

        # Finalize log-chroma-histogram vis:
        if do_lch_vid:
            vid_lch.release()
            vid_time.print_avg()

        # Finalize log-chroma-histogram vis:
        hist_time.print_avg()

        # Finalize subsequent frame analysis:
        if do_subsequent_frame:
            pd.DataFrame(frame_wise_data).to_csv(subsequent_frame_dir) # Write DataFrame to file

        # Finalize subsequent cut analysis:
        if do_subsequent_cut:
            pd.DataFrame(cut_wise_data).to_csv(subsequent_cut_dir) # Write DataFrame to file

        # Finalize cut stddev analysis:
        if do_cut_stddev:
            #print(cuts_for_stddev)
            cuts_sttdev_stack = np.stack(cuts_for_stddev)
            #print_ndarray_metrics(cuts_sttdev_stack, "cuts_sttdev_stack")
            cuts_sttdev = np.nanstd(cuts_sttdev_stack, axis=0) # Ignoring
            if np.isnan(cuts_sttdev[0,0]): #Trying to avoid strange error
                print("Stddev Calculation Failed!")
                #print(cuts_for_stddev)
                #print_ndarray_metrics(cuts_sttdev, "cuts_sttdev")
            else:
                np.save(cut_stddev_dir, cuts_sttdev)
        
        # Show total iteration time:
        iter_time.print_avg()

        #plt.imshow(cuts_sttdev)
    #print()

# %%
for i, vid_file in enumerate(cinematic):
    if i < 244:
        continue
    try:
        yt_id = vid_file.split(".")[0]
        file_dir = os.path.join(dataset_folder, vid_file)
        print(f"Processing Video {file_dir} - {i}/{len(cinematic)}")
        collect_video_stats(
            file_dir,
            vid_cut_folder="../../data/cuts/",
            subsequent_frame_folder="../../data/analysis/variation_hist_metrics",
            subsequent_cut_folder="../../data/analysis/variation_hist_metrics",
            cut_stddev_folder="../../data/analysis/temporal_hist_std",
            lch_vis_folder="../../data/analysis/variation_hist_videos"
        )
    except Exception as e:
        print(e)
# Out:
# Processing Video ../../data/eGjXwDYpOLE.mp4 - 244/1855
# Processing Video ../../data/SEJuBrGzPZ4.mp4 - 245/1855
# Processing Video ../../data/6acRHWnfZAE.mp4 - 246/1855
# Processing Video ../../data/aLXfp9CufV0.mp4 - 247/1855
# Processing Video ../../data/fpj7i2CPt8M.mp4 - 248/1855
# Average time for function hist: 0.005377087160299181
# Average time for function Total Iteration: 0.005497709611158145
# Processing Video ../../data/tbayiPxkUMM.mp4 - 249/1855
# Average time for function hist: 0.004838517948723676
# Average time for function Total Iteration: 0.0049609266090811345
# Processing Video ../../data/3WRxsmqercg.mp4 - 250/1855
# Average time for function hist: 0.004921491658256629
# Average time for function Total Iteration: 0.005044040375052191
# Processing Video ../../data/YLorLVa95Xo.mp4 - 251/1855
# Average time for function hist: 0.004932476832948882
# Average time for function Total Iteration: 0.005053127486130287
# Processing Video ../../data/dgC9Q0uhX70.mp4 - 252/1855
# Average time for function hist: 0.004870350113009462
# Average time for function Total Iteration: 0.004980814855287571
# Processing Video ../../data/CfBewQPFdKE.mp4 - 253/1855
# Average time for function hist: 0.004574105143547058
# Average time for function Total Iteration: 0.00465105579179876
# Processing Video ../../data/X2i9Zz_AqTg.mp4 - 254/1855
# Average time for function hist: 0.00505391233845761
# Average time for function Total Iteration: 0.005178952556953095
# Processing Video ../../data/6k8qeqZycgE.mp4 - 255/1855
# Processing Video ../../data/uMwECVb1q54.mp4 - 256/1855
# Average time for function hist: 0.0038548206513927827
# Average time for function Total Iteration: 0.003920160878089166
# Processing Video ../../data/w3ugHP-yZXw.mp4 - 257/1855
# Average time for function hist: 0.004977991230979317
# Average time for function Total Iteration: 0.0050984688012386415
# Processing Video ../../data/q1zlkaPpMsA.mp4 - 706/1855
# Average time for function hist: 0.03320085306801324
# Average time for function Total Iteration: 0.03404330608330824
# Processing Video ../../data/lg5hj2c5Nkk.mp4 - 707/1855
# Average time for function hist: 0.03947451856839099
# Average time for function Total Iteration: 0.040234435491325445
# Processing Video ../../data/uW_GNKVuZ1c.mp4 - 708/1855
# Average time for function hist: 0.033448878691826035
# Average time for function Total Iteration: 0.034328640281379996
# Processing Video ../../data/f6acw690AqQ.mp4 - 709/1855
# Average time for function hist: 0.031427242523860525
# Average time for function Total Iteration: 0.032243441123047736
# Processing Video ../../data/KRYURVuIC3o.mp4 - 710/1855
# Average time for function hist: 0.03120500484336382
# Average time for function Total Iteration: 0.032040667676714506
# Processing Video ../../data/c3z4PFjbf64.mp4 - 711/1855
# Processing Video ../../data/OgBqfw0hINM.mp4 - 712/1855
# Processing Video ../../data/9O1Iy9od7-A.mp4 - 713/1855
# Average time for function hist: 0.0295191732687816
# Average time for function Total Iteration: 0.030282136232306415
# Processing Video ../../data/x_-x4Dwz-rU.mp4 - 714/1855
# Average time for function hist: 0.031047862528596953
# Average time for function Total Iteration: 0.03183112763187974
# Processing Video ../../data/g06k4HOlEbg.mp4 - 715/1855
# Average time for function hist: 0.019080891597925805
# Average time for function Total Iteration: 0.02046961257673197
# Processing Video ../../data/Ee92mDZu_PI.mp4 - 716/1855
# Average time for function hist: 0.03388980140906477
# Average time for function Total Iteration: 0.03460352677989281
# Processing Video ../../data/hEcB7T-C0g8.mp4 - 717/1855
# Average time for function hist: 0.030018280430506635
# Average time for function Total Iteration: 0.03075106914645882
# Processing Video ../../data/mP0VHJYFOAU.mp4 - 718/1855
# Average time for function hist: 0.031307633030236065
# Average time for function Total Iteration: 0.0321157744905384
# Processing Video ../../data/FsyBwLYDidA.mp4 - 719/1855
# Average time for function hist: 0.029699178015599487
# Average time for function Total Iteration: 0.03045628474709766
# Processing Video ../../data/vw61gCe2oqI.mp4 - 720/1855
# Average time for function hist: 0.03185384686476265
# Average time for function Total Iteration: 0.03269042376599281
# Processing Video ../../data/7dd4pogcc4Y.mp4 - 721/1855
# Average time for function hist: 0.03518533658596777
# Average time for function Total Iteration: 0.03603312853843935
# Processing Video ../../data/n3iorawVQkw.mp4 - 722/1855
# Average time for function hist: 0.04189055765643116
# Average time for function Total Iteration: 0.04267007901708663
# Processing Video ../../data/WR7cc5t7tv8.mp4 - 723/1855
# Average time for function hist: 0.03131788483436106
# Average time for function Total Iteration: 0.0321147779637992
# Processing Video ../../data/Tjtv8tVtVRw.mp4 - 724/1855
# Average time for function hist: 0.027516122612556097
# Average time for function Total Iteration: 0.028249928562376965
# Processing Video ../../data/65AjY_nRdqE.mp4 - 725/1855
# Average time for function hist: 0.030838757183901062
# Average time for function Total Iteration: 0.03160438890669756
# Processing Video ../../data/t-0XuYxh67w.mp4 - 726/1855
# Processing Video ../../data/C1no75lpOiw.mp4 - 727/1855
# Processing Video ../../data/LAZOmwkRq_A.mp4 - 728/1855
# Average time for function hist: 0.03428194394892892
# Average time for function Total Iteration: 0.035085972648225626
# Processing Video ../../data/I_tOrWWRivM.mp4 - 770/1855
# Average time for function hist: 0.03536434708354629
# Average time for function Total Iteration: 0.036251847617722745
# Processing Video ../../data/AGACeWVdFqo.mp4 - 771/1855
# Average time for function hist: 0.03416142903321178
# Average time for function Total Iteration: 0.03496415917908738
# Processing Video ../../data/lyy7y0QOK-0.mp4 - 772/1855
# Average time for function hist: 0.03561693643282396
# Average time for function Total Iteration: 0.036491670086171775
# Processing Video ../../data/F4gJsKZvqE4.mp4 - 773/1855
# Average time for function hist: 0.034253729848080346
# Average time for function Total Iteration: 0.03539418659092468
# Processing Video ../../data/V1tE1eGkvL0.mp4 - 774/1855
# Average time for function hist: 0.026431462159653404
# Average time for function Total Iteration: 0.02825795892998953
# Processing Video ../../data/UuWmCVdwhKg.mp4 - 775/1855
# Average time for function hist: 0.025320875816403056
# Average time for function Total Iteration: 0.02715352216030812
# Processing Video ../../data/Bnsesxk5LF4.mp4 - 776/1855
# Average time for function hist: 0.02688330847883849
# Average time for function Total Iteration: 0.02807784549013496
# Processing Video ../../data/dB7a9utApIQ.mp4 - 777/1855
# Average time for function hist: 0.02333971550934916
# Average time for function Total Iteration: 0.024012576609528217
# Processing Video ../../data/A67eVTHqYAE.mp4 - 778/1855
# Average time for function hist: 0.0288243836113819
# Average time for function Total Iteration: 0.029561170707681023
# Processing Video ../../data/b7yOuhI1dzU.mp4 - 779/1855
# Average time for function hist: 0.03704687393775521
# Average time for function Total Iteration: 0.03780022386282478
# Processing Video ../../data/ArdNQUUcZOM.mp4 - 780/1855
# Average time for function hist: 0.027957734329346968
# Average time for function Total Iteration: 0.028645350915610594
# Processing Video ../../data/nOfH7uEojKk.mp4 - 781/1855
# Average time for function hist: 0.020883047040571527
# Average time for function Total Iteration: 0.022353294526312198
# Processing Video ../../data/mn4O3iQ8B_s.mp4 - 782/1855
# Average time for function hist: 0.02970908077847955
# Average time for function Total Iteration: 0.030421546407633428
# Processing Video ../../data/7wd5KEaOtm4.mp4 - 783/1855
# Average time for function hist: 0.029281608562192297
# Average time for function Total Iteration: 0.02998520375474826
# Processing Video ../../data/uU-ET1FAv3Y.mp4 - 784/1855
# Average time for function hist: 0.03163751205766058
# Average time for function Total Iteration: 0.03241089778227676
# Processing Video ../../data/sRfnevzM9kQ.mp4 - 785/1855
# Average time for function hist: 0.03089202705524817
# Average time for function Total Iteration: 0.03166494809143932
# Processing Video ../../data/JEsqrtp8SAk.mp4 - 786/1855
# Average time for function hist: 0.031877659931194374
# Average time for function Total Iteration: 0.032638657575065136
# Processing Video ../../data/HdVvjvW_OEo.mp4 - 787/1855
# Average time for function hist: 0.0208365545259271
# Average time for function Total Iteration: 0.022424261368329253
# Processing Video ../../data/1FJD7jZqZEk.mp4 - 788/1855
# Processing Frame 3202/3604

# %%
cut_stddev_folder="../../data/analysis/temporal_hist_std"
for f in os.listdir(cut_stddev_folder):
    if f[-4:] == '.npy':
        d = os.path.join(cut_stddev_folder, f)
        m = np.load(d)
        if np.isnan(m[0,0]):
            os.remove(d)
