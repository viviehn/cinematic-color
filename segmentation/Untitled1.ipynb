# %%
import glob
from PIL import Image
import numpy as np
import random
import json
import data_utils as utils
import matplotlib.pyplot as plt
from skimage import filters
from skimage import color, io
import cv2 as cv

# %%
im = np.asarray(Image.open('source2.jpg'))
plt.imshow(im)
plt.show()
im2 = np.asarray(Image.open('target2.jpg'))
plt.imshow(im2)
plt.show()

mask = np.asarray(Image.open('source2_mask.jpg'))[:,:,0]
plt.imshow(mask)
plt.show()
mask2 = np.asarray(Image.open('target2_mask.jpg'))[:,:,0]
plt.imshow(mask2)
plt.show()

# %%
# Out:
# (549, 1920, 3)
